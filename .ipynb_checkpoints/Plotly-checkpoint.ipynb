# %% [markdown]
# # Plotly the Alternative to Matplotlib

# %%
# Hey there this is a tutorial is going to go over using Plotly in Jupyter

# %% [markdown]
# ## HOWTO
# 1. Go to Plotly and sign up for an account https://plot.ly/feed
# 2. Navigate to your name and select settings/profile to obtain your API key

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pylab import *
import pylab as pl
pd.set_option('display.width', 300)
pd.set_option('display.max_columns', 300)

# %% [markdown]
# ## Pandas
# 1. Go to open secrets and download
# http://www.opensecrets.org/politicians/contrib.php?type=C&cid=N00007727&newMem=N&cycle=2014
# 2. Upload open secrets to Pandas
# 3. Select  columns

# %% [markdown]
# ## Putting politician information into a dataframe

# %%
contributors = pd.read_csv('blumenauer_data.csv')
contributors
# Out:
#             id  cycle                                    recip                                         orgname  indiv    pac  totals                          Origin                                             Source
# 0    N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)          Intl Brotherhood of Electrical Workers      0  20000   20000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 1    N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                       Amalgamated Transit Union      0  15000   15000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 2    N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                     United Transportation Union      0  12500   12500  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 3    N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)        American Fedn of St/Cnty/Munic Employees      0  11000   11000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 4    N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                Cow Creek Band of Umpqua Indians  10200      0   10200  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 5    N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                         LTK Consulting Services      0  10200   10200  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 6    N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                       Operating Engineers Union      0  10000   10000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 7    N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                  Painters & Allied Trades Union      0  10000   10000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 8    N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)          United Food & Commercial Workers Union      0  10000   10000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 9    N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                                 Teamsters Union      0  10000   10000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 10   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                 American Federation of Teachers      0  10000   10000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 11   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)        American Academy of Orthopaedic Surgeons      0  10000   10000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 12   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                       American Assn for Justice      0   9000    9000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 13   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                                        Nike Inc   4000   5000    9000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 14   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                           United Parcel Service      0   8000    8000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 15   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                         Honeywell International      0   7999    7999  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 16   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                            Metro West Ambulance   7500      0    7500  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 17   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)  National Assn of Real Estate Investment Trusts      0   7500    7500  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 18   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                       National Assn of Realtors      0   7500    7500  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 19   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)        Employee-Owned S Corporations of America      0   7000    7000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 20   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)      Association for Advanced Life Underwriting      0   7000    7000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 21   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                              Berkshire Hathaway      0   6500    6500  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 22   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)            National Electrical Contractors Assn      0   6500    6500  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 23   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                   Vernier Software & Technology   6250      0    6250  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 24   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                                      Intel Corp      0   6250    6250  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 25   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                  American College of Physicians      0   6000    6000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 26   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                   American Postal Workers Union      0   6000    6000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 27   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)           National Air Traffic Controllers Assn      0   6000    6000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 28   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                            Greenbrier Companies   5200      0    5200  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 29   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                         Herbalife International      0   5000    5000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# ..         ...    ...                                      ...                                             ...    ...    ...     ...                             ...                                                ...
# 88   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                   American Academy of Neurology      0   2500    2500  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 89   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                                         AFL-CIO      0   2500    2500  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 90   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                  American College of Cardiology      0   2500    2500  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 91   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                           Bingham McCutchen LLP   2500      0    2500  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 92   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                      Credit Union National Assn      0   2500    2500  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 93   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                                  Balfour Beatty      0   2500    2500  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 94   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)             International Assn of Fire Fighters      0   2500    2500  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 95   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                                Akin, Gump et al    500   1875    2375  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 96   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                                Van Scoyoc Assoc   1000   1231    2231  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 97   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                                      Terex Corp   2000      0    2000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 98   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                       Shiels Obletz Johnsen Inc   2000      0    2000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 99   N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                                    Rapoza Assoc   2000      0    2000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 100  N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                        National Football League      0   2000    2000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 101  N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)    National Telecommunications Cooperative Assn      0   2000    2000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 102  N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                                 Novogradac & Co   2000      0    2000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 103  N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                     National Confectioners Assn      0   2000    2000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 104  N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                                        MMC Corp      0   2000    2000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 105  N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                                       K&L Gates      0   2000    2000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 106  N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                                       AFLAC Inc      0   2000    2000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 107  N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)               American Council of Life Insurers      0   2000    2000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 108  N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)           American Society of Anesthesiologists      0   2000    2000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 109  N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)             American Society of Assn Executives      0   2000    2000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 110  N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                  American Physical Therapy Assn      0   2000    2000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 111  N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)           American Federation of Govt Employees      0   2000    2000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 112  N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                International Longshoremens Assn      0   2000    2000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 113  N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                             International Paper      0   2000    2000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 114  N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                                 Caterpillar Inc      0   2000    2000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 115  N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                                      Fluor Corp      0   2000    2000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 116  N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)          Association of Equipment Manufacturers      0   2000    2000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
# 117  N00007727   2014  Earl Blumenauer (D) + Leadership Pac(s)                                         CRH PLC      0   2000    2000  Center for Responsive Politics  http://www.opensecrets.org/politicians/contrib...
#
# [118 rows x 9 columns]

# %%
## Query for the top ten donors of Earl Blumenauer
#recession_employment = contributors.loc[contributors['totals'] == 2008]

top_ten = contributors.sort(['totals'], ascending=False)[:10]
top_ten

#Create a new dataframe
top_contributors = top_ten[['orgname', 'totals']]
top_contributors
# Out:
#                                      orgname  totals
# 0     Intl Brotherhood of Electrical Workers   20000
# 1                  Amalgamated Transit Union   15000
# 2                United Transportation Union   12500
# 3   American Fedn of St/Cnty/Munic Employees   11000
# 4           Cow Creek Band of Umpqua Indians   10200
# 5                    LTK Consulting Services   10200
# 11  American Academy of Orthopaedic Surgeons   10000
# 10           American Federation of Teachers   10000
# 9                            Teamsters Union   10000
# 8     United Food & Commercial Workers Union   10000

# %% [markdown]
# ## Matplotlib

# %%
# %pylab inline

top_contributors.plot(kind='Bar')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['info', 'linalg', 'draw_if_interactive', 'random', 'fft', 'power']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# ## Great, it is now time to plot with Plotly

# %% [markdown]
# 1. First import plotly
# 2. Find your username, and API key

# %%
import plotly.plotly as py
from plotly.graph_objs import *

py.sign_in("porsh", "bjolm8bq82")

data = Data([
    Bar(
        x=['Cow Creek Band of Indians', 'American St/Cnty/Munic Employees','United Transportation Union', 'Amalgamated Transit Union', 'Int Brotherhood of Electrical Workers'],
        y=[10200, 11000, 12500, 15000, 20000],
        text=['Gave $100,000 locally and federally(2014)', 'Given $4,792,675 locally and federally(2014)', 'Given $1,055,500 locally and federally(2014)', 'Given $1626,200 locally and federally(2014)', 'Given $3,522,020 locally and federally(2014)'],
        marker=Marker(
            color='rgb(142, 124, 195)'
        )
    )
])
layout = Layout(
    title='5 top donors of Oregon State Representative Earl Blumenauer',
    font=Font(
        family='Raleway, sans-serif'
    ),
    showlegend=False,
    xaxis=XAxis(
        tickangle=-45
    ),
    yaxis=YAxis(
        zeroline=False,
        gridwidth=2
    ),
    bargap=0.05
)
fig = Figure(data=data, layout=layout)

plot_url = py.plot(fig, filename='bar-with-hover-text')

# %%
The Final Product:
    https://plot.ly/~porsh/1
# Out:
#   File "<ipython-input-9-8e60606a3591>", line 1
#     The Final Product:
#             ^
# SyntaxError: invalid syntax

# %%
Sources:
    https://www.opensecrets.org
